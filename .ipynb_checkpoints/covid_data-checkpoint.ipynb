# %%
# Get API_KEY from https://covidactnow.org/data-api
import pandas as pd
from config import API_KEY

# %%
# Totals for 50 states
covid_df = pd.read_csv(f'https://api.covidactnow.org/v2/states.csv?apiKey={API_KEY}')
covid_df.head()
# Out:
#    fips country state  county  level  lat          locationId  long  \
# 0     2      US    AK     NaN  state  NaN  iso1:us#iso2:us-ak   NaN
# 1     1      US    AL     NaN  state  NaN  iso1:us#iso2:us-al   NaN
# 2     5      US    AR     NaN  state  NaN  iso1:us#iso2:us-ar   NaN
# 3     4      US    AZ     NaN  state  NaN  iso1:us#iso2:us-az   NaN
# 4     6      US    CA     NaN  state  NaN  iso1:us#iso2:us-ca   NaN
#
#    population  metrics.testPositivityRatio  ... actuals.vaccinationsCompleted  \
# 0      731545                        0.067  ...                      450047.0
# 1     4903185                        0.033  ...                     2479239.0
# 2     3017804                        0.023  ...                     1625623.0
# 3     7278717                        0.032  ...                     4412629.0
# 4    39512223                        0.014  ...                    28043765.0
#
#    lastUpdatedDate                                       url  \
# ...

# %%
covid_df.columns
# Out:
# Index(['fips', 'country', 'state', 'county', 'level', 'lat', 'locationId',
#        'long', 'population', 'metrics.testPositivityRatio',
#        'metrics.testPositivityRatioDetails.source', 'metrics.caseDensity',
#        'metrics.contactTracerCapacityRatio', 'metrics.infectionRate',
#        'metrics.infectionRateCI90', 'unused1', 'unused2', 'unused3', 'unused4',
#        'unused5', 'metrics.icuCapacityRatio', 'riskLevels.overall',
#        'riskLevels.testPositivityRatio', 'riskLevels.caseDensity',
#        'riskLevels.contactTracerCapacityRatio', 'riskLevels.infectionRate',
#        'unused6', 'riskLevels.icuCapacityRatio', 'actuals.cases',
#        'actuals.deaths', 'actuals.positiveTests', 'actuals.negativeTests',
#        'actuals.contactTracers', 'actuals.hospitalBeds.capacity',
#        'actuals.hospitalBeds.currentUsageTotal',
#        'actuals.hospitalBeds.currentUsageCovid', 'unused7',
#        'actuals.icuBeds.capacity', 'actuals.icuBeds.currentUsageTotal',
# ...

# %%
covid_df.drop(columns = ['unused1', 'unused2', 'unused3', 'unused4', 'unused5', 'unused6', 'unused7', 'unused8'], axis = 1)
# Out:
#     fips country state  county  level  lat          locationId  long  \
# 0      2      US    AK     NaN  state  NaN  iso1:us#iso2:us-ak   NaN
# 1      1      US    AL     NaN  state  NaN  iso1:us#iso2:us-al   NaN
# 2      5      US    AR     NaN  state  NaN  iso1:us#iso2:us-ar   NaN
# 3      4      US    AZ     NaN  state  NaN  iso1:us#iso2:us-az   NaN
# 4      6      US    CA     NaN  state  NaN  iso1:us#iso2:us-ca   NaN
# 5      8      US    CO     NaN  state  NaN  iso1:us#iso2:us-co   NaN
# 6      9      US    CT     NaN  state  NaN  iso1:us#iso2:us-ct   NaN
# 7     11      US    DC     NaN  state  NaN  iso1:us#iso2:us-dc   NaN
# 8     10      US    DE     NaN  state  NaN  iso1:us#iso2:us-de   NaN
# 9     12      US    FL     NaN  state  NaN  iso1:us#iso2:us-fl   NaN
# 10    13      US    GA     NaN  state  NaN  iso1:us#iso2:us-ga   NaN
# 11    15      US    HI     NaN  state  NaN  iso1:us#iso2:us-hi   NaN
# 12    19      US    IA     NaN  state  NaN  iso1:us#iso2:us-ia   NaN
# ...

# %%
len(covid_df)
# Out:
# 53

# %%
# Time series for all states
covid_df = pd.read_csv(f'https://api.covidactnow.org/v2/states.timeseries.csv?apiKey={API_KEY}')

# %%
covid_df.head()
# Out:
#          date country state  county  fips  lat  long          locationId  \
# 0  2020-03-01      US    AK     NaN     2  NaN   NaN  iso1:us#iso2:us-ak
# 1  2020-03-02      US    AK     NaN     2  NaN   NaN  iso1:us#iso2:us-ak
# 2  2020-03-03      US    AK     NaN     2  NaN   NaN  iso1:us#iso2:us-ak
# 3  2020-03-04      US    AK     NaN     2  NaN   NaN  iso1:us#iso2:us-ak
# 4  2020-03-05      US    AK     NaN     2  NaN   NaN  iso1:us#iso2:us-ak
#
#    actuals.cases  actuals.deaths  ...  metrics.icuCapacityRatio  \
# 0            NaN             NaN  ...                       NaN
# 1            NaN             NaN  ...                       NaN
# 2            NaN             NaN  ...                       NaN
# 3            NaN             NaN  ...                       NaN
# 4            NaN             NaN  ...                       NaN
#
#    riskLevels.overall  metrics.vaccinationsInitiatedRatio  \
# 0                   0                                 NaN
# ...

# %%
len(covid_df)
# Out:
# 40031
